# %% [markdown]
# # Problem Statement
# An Ad- Agency analyzed a dataset of online ads and used a machine learning model to predict whether a user would click on an ad or not.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ## Data Loading

# %%
df_submission=pd.read_csv('sampleSubmission.csv')
df_test=pd.read_csv('test.csv')
df_train=pd.read_csv('train.csv')

# %%
pd_submission
# Out:
#                            id  click
# 0        10000174058809263569    0.5
# 1        10000182526920855428    0.5
# 2        10000554139829213984    0.5
# 3        10001094637809798845    0.5
# 4        10001377041558670745    0.5
# ...                       ...    ...
# 4577459   9998166651591969718    0.5
# 4577460   9998249812366450951    0.5
# 4577461     99988023653614546    0.5
# 4577462   9999086574712596585    0.5
# 4577463     99992636456518364    0.5
#
# [4577464 rows x 2 columns]

# %%
pd_test
# Out:
#                    id      hour    C1  banner_pos   site_id site_domain  \
# 0        1.000017e+19  14103100  1005           0  235ba823    f6ebf28e
# 1        1.000018e+19  14103100  1005           0  1fbe01fe    f3845767
# 2        1.000055e+19  14103100  1005           0  1fbe01fe    f3845767
# 3        1.000109e+19  14103100  1005           0  85f751fd    c4e18dd6
# 4        1.000138e+19  14103100  1005           0  85f751fd    c4e18dd6
# ...               ...       ...   ...         ...       ...         ...
# 4577459  9.998167e+18  14103123  1005           0  93eaba74    7687a86e
# 4577460  9.998250e+18  14103123  1005           0  17d1b03f    f3845767
# 4577461  9.998802e+16  14103123  1005           0  5b08c53b    7687a86e
# 4577462  9.999087e+18  14103123  1005           0  85f751fd    c4e18dd6
# 4577463  9.999264e+16  14103123  1005           0  17d1b03f    f3845767
#
#         site_category    app_id app_domain app_category  ... device_type  \
# ...

# %%
pd_train
# Out:
#                     id  click      hour    C1  banner_pos   site_id  \
# 0         1.000009e+18      0  14102100  1005           0  1fbe01fe
# 1         1.000017e+19      0  14102100  1005           0  1fbe01fe
# 2         1.000037e+19      0  14102100  1005           0  1fbe01fe
# 3         1.000064e+19      0  14102100  1005           0  1fbe01fe
# 4         1.000068e+19      0  14102100  1005           1  fe8cc448
# ...                ...    ...       ...   ...         ...       ...
# 40428962  9.998753e+18      1  14103023  1005           1  e151e245
# 40428963  9.999038e+18      0  14103023  1005           0  85f751fd
# 40428964  9.999585e+18      0  14103023  1005           1  f61eaaae
# 40428965  9.999636e+18      1  14103023  1005           0  85f751fd
# 40428966  9.999747e+18      0  14103023  1005           0  1fbe01fe
#
#          site_domain site_category    app_id app_domain  ... device_type  \
# 0           f3845767      28905ebd  ecad2386   7801e8d9  ...           1
# ...

# %% [markdown]
# ## Data Understanding

# %%
df_train.isnull().sum()
# Out:
# id                  0
# click               0
# hour                0
# C1                  0
# banner_pos          0
# site_id             0
# site_domain         0
# site_category       0
# app_id              0
# app_domain          0
# app_category        0
# device_id           0
# device_ip           0
# device_model        0
# device_type         0
# device_conn_type    0
# C14                 0
# C15                 0
# C16                 0
# C17                 0
# C18                 0
# C19                 0
# C20                 0
# C21                 0
# dtype: int64

# %%
df_train.dtypes
# Out:
# id                  float64
# click                 int64
# hour                  int64
# C1                    int64
# banner_pos            int64
# site_id              object
# site_domain          object
# site_category        object
# app_id               object
# app_domain           object
# app_category         object
# device_id            object
# device_ip            object
# device_model         object
# device_type           int64
# device_conn_type      int64
# C14                   int64
# C15                   int64
# C16                   int64
# C17                   int64
# C18                   int64
# C19                   int64
# C20                   int64
# C21                   int64
# dtype: object

# %%
df_target=df_train.iloc[:,:2]

# %%
df_target
# Out:
#                     id  click
# 0         1.000009e+18      0
# 1         1.000017e+19      0
# 2         1.000037e+19      0
# 3         1.000064e+19      0
# 4         1.000068e+19      0
# ...                ...    ...
# 40428962  9.998753e+18      1
# 40428963  9.999038e+18      0
# 40428964  9.999585e+18      0
# 40428965  9.999636e+18      1
# 40428966  9.999747e+18      0
#
# [40428967 rows x 2 columns]

# %% [markdown]
# # Data Analysis
# We will do a Univariate and a Bivariate analysis of the given data for a better understanding.

# %%
df_train_num= df_train.select_dtypes(include=np.number)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-79bb62c906a2> in <module>
#       1 df_train_num= df_train.select_dtypes(include=np.number)
# ----> 2 df_train_category= df_train.select_dtypes(include='object')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3602             keep_these &= ~self.dtypes.isin(excluded_dtypes)
#    3603
# -> 3604         return self.iloc[:, keep_these.values]
#    3605
#    3606     def insert(self, loc, column, value, allow_duplicates=False) -> None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
# ...

# %%
df_train_category= df_train.select_dtypes(include='object')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-21-1dd4bfd6ba35> in <module>
# ----> 1 df_train_category= df_train.select_dtypes(include='object')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3602             keep_these &= ~self.dtypes.isin(excluded_dtypes)
#    3603
# -> 3604         return self.iloc[:, keep_these.values]
#    3605
#    3606     def insert(self, loc, column, value, allow_duplicates=False) -> None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ...

# %%
df_train_category
# Out:
#            site_id site_domain site_category    app_id app_domain  \
# 0         1fbe01fe    f3845767      28905ebd  ecad2386   7801e8d9
# 1         1fbe01fe    f3845767      28905ebd  ecad2386   7801e8d9
# 2         1fbe01fe    f3845767      28905ebd  ecad2386   7801e8d9
# 3         1fbe01fe    f3845767      28905ebd  ecad2386   7801e8d9
# 4         fe8cc448    9166c161      0569f928  ecad2386   7801e8d9
# ...            ...         ...           ...       ...        ...
# 40428962  e151e245    7e091613      f028772b  ecad2386   7801e8d9
# 40428963  85f751fd    c4e18dd6      50e219e0  9c13b419   2347f47a
# 40428964  f61eaaae    6b59f079      f028772b  ecad2386   7801e8d9
# 40428965  85f751fd    c4e18dd6      50e219e0  3c4b944d   2347f47a
# 40428966  1fbe01fe    f3845767      28905ebd  ecad2386   7801e8d9
#
#          app_category device_id device_ip device_model
# 0            07d7df22  a99f214a  ddd2926e     44956a24
# 1            07d7df22  a99f214a  96809ac8     711ee120
# ...

# %% [markdown]
# ## Univariate Analysis
